# %%
from math import sqrt
def LeerArchivo(filename,filename2):
    file =open(filename)
    file2 =open(filename2,"w")
    i=-1
    for line in file:
        s=str(line)
        s=s[:len(s)-1]
        if i!=-1:
            print(line.split(';')[2],line.split(';')[0])
            jcon=-1
            conecciones=[[0,999],[0,999],[0,999],[0,999],[0,999]]
            fileaux=open (filename)
            for line2 in fileaux:
                if jcon!=-1:
                    if jcon!=int(line.split(';')[0]):
                        p=Pitagoras(float(line.split(';')[2]),float(line.split(';')[3]),float(line2.split(';')[2]),float(line2.split(';')[3]))
                        if jcon<5:
                            conecciones[jcon]=jcon,p
                        else:
                            conecciones.sort(key=lambda tup: tup[1])
                            for k in range(5):
                                if conecciones[k][1]>p:
                                    conecciones[4]=jcon,p
                                    break
                        
                        if jcon==145225:
                            conecciones.sort(key=lambda tup: tup[1])
                            for k in range(5):
                                print (str(conecciones[k][0])+";"+str(conecciones[k][1]))
                                s=s+";"+str(conecciones[k][0])+";"+str(conecciones[k][1])
                            break 
                        
                jcon+=1
            fileaux.close()
        else:
            s=s+"Con1;Dis1;Con2;Dis2;Con3;Dis3;Con4;Dis4;Con5;Dis5"
        file2.write(s)
        file2.write("\n")
        i+=1
        if 145225%i==0:
            print((145225/i)*100)
        if i==145225:
            break
    file.close()
    file2.close()
def Pitagoras(x,y,x1,y1):
    return sqrt((x-x1)**2 + (y-y1)**2)
def bubbleSort(alist):
    for passnum in range(len(alist)-1,0,-1):
        for i in range(passnum):
            if alist[i][1]>alist[i+1][1]:
                temp = alist[i]
                alist[i]= alist[i+1]
                alist[i+1] = temp

LeerArchivo('BDO.csv','BD.txt')
# Out:
# -72.53126621200 0
# 5;1.5395538839986203
# 13;1.7764228618444449
# 1;2.9845302788560355
# 3;3.159015391400545
# 2;3.175224693816546
# -73.68263125400 1
# 2;0.19235354339982622
# 13;1.4561787893383369
# 5;2.8282140247580214
# 0;2.9845302788560355
# 7;3.0679364350958758
# -73.73216629000 2
# 1;0.19235354339982622
# 13;1.6408137764496187
# 5;2.981484223298616
# 7;3.0669491299972838
# 0;3.175224693816546
# -75.69002866700 3
# 4;0.10056573988137786
# 7;2.330026840243892
# 13;2.362419929074341
# 0;3.159015391400545
# 1;3.439936649354556
# -75.76846718800 4
# 3;0.10056573988137786
# 7;2.2402977506232107
# 13;2.3933307008888556
# 0;3.2372824007700833
# 1;3.43606967093071
# -71.41628372700 5
# 0;1.5395538839986203
# 13;2.3391767920648974
# 1;2.8282140247580214
# 2;2.981484223298616
# 3;4.413435231678225
# -80.25141477600 6
# 9;1.442426178889728
# 16;1.7428805429107914
# 15;1.8209601146501357
# 17;2.162531095066466
# 10;2.30296580790664
# -76.67394340000 7
# 4;2.2402977506232107
# 3;2.330026840243892
# 11;2.66033775794267
# 20;2.9969364080031946
# 13;3.0308860981466426
# -77.32246398900 8
# 12;0.5056584175920917
# 19;1.1438826222168437
# 14;1.6072626383017221
# 18;1.6222953360803745
# 17;1.9265684084970534
# -79.67296421500 9
# 15;0.3883620040665112
# 17;0.8424888001249307
# 10;0.9327874078461815
# 16;1.0146177202130877
# 18;1.1971593194429122
# -79.76048469500 10
# 15;0.5651797477806846
# 9;0.9327874078461815
# 17;0.9971447566148328
# 16;1.0111094060902812
# 18;1.337958617703779
# -77.55023717900 11
# 20;0.4224691148505063
# 7;2.66033775794267
# 8;2.9441064520335374
# 19;3.0440321240326953
# 12;3.0778428602466694
# -76.81976437600 12
# 8;0.5056584175920917
# 19;1.6484177230194181
# 14;1.9790474006539422
# 18;1.9982850822644775
# 17;2.3367909960188915
# -73.74342620400 13
# 1;1.4561787893383369
# 2;1.6408137764496187
# 0;1.7764228618444449
# 5;2.3391767920648974
# 3;2.362419929074341
# -78.51179147000 14
# 18;0.02803959007282897
# 17;0.41236921322691805
# 15;1.0997727103394976
# 19;1.114284152246049
# 9;1.2203989167193596
# -79.61153577000 15
# 9;0.3883620040665112
# 10;0.5651797477806846
# 17;0.6875076949439436
# 16;1.0006672241730856
# 18;1.0727547929325767
# -80.61220295000 16
# 15;1.0006672241730856
# 10;1.0111094060902812
# 9;1.0146177202130877
# 17;1.6881720237371307
# 6;1.7428805429107914
# -78.92403222000 17
# 18;0.3852605970866059
# 14;0.41236921322691805
# 15;0.6875076949439436
# 9;0.8424888001249307
# 10;0.9971447566148328
# -78.53878102000 18
# 14;0.02803959007282897
# 17;0.3852605970866059
# 15;1.0727547929325767
# 19;1.1081366769969767
# 9;1.1971593194429122
# -78.46589243800 19
# 18;1.1081366769969767
# 14;1.114284152246049
# 8;1.1438826222168437
# 17;1.1944047679709973
# 10;1.4106138015280545

# %% [markdown]
# from math import sqrt
# def LeerArchivo(filename,filename2):
#     file =open(filename)
#     fileaux=open (filename)
#     file2 =open(filename2,"w")
#     i=-1
#     for line in file:
#         s=str(line)
#         s=s[:len(s)-1]
#         if i!=-1:
#             print(line.split(';')[2])
#             x=float(line.split(';')[2])
#             y=float(line.split(';')[3])
#             jcon=-1
#             conecciones=[[0,999],[0,999],[0,999],[0,999],[0,999]]
#             for line2 in fileaux:
#                 if jcon!=-1:
#                     a=float(line2.split(';')[2])
#                     b=float(line2.split(';')[3])
#                     p=Pitagoras(x,y,a,b)
#                     if jcon<5:
#                         conecciones[jcon][0]=jcon
#                         conecciones[jcon][1]=p
#                     else:
#                         bubbleSort(conecciones)
#                         for k in range(5):
#                             if conecciones[k][1]>p:
#                                 conecciones[4][0]=jcon
#                                 conecciones[4][1]=p
#                                 break
#                     bubbleSort(conecciones)
#                     if jcon==20:
#                         for k in range(5):
#                             print (str(conecciones[k][0])+";"+str(conecciones[k][1]))
#                             s=s+";"+str(conecciones[k][0])+";"+str(conecciones[k][1])
#                         break
#                 jcon+=1
#         else:
#             s=s+"Con1;Dis1;Con2;Dis2;Con3;Dis3;Con4;Dis4;Con5;Dis5"
#         file2.write(s)
#         file2.write("\n")
#         i+=1
#         if i==20:
#             break
#     file.close()
#     file2.close()
# def Pitagoras(x,y,x1,y1):
#     return sqrt((x-x1)**2 + (y-y1)**2)
# def bubbleSort(alist):
#     for passnum in range(len(alist)-1,0,-1):
#         for i in range(passnum):
#             if alist[i][1]>alist[i+1][1]:
#                 temp = alist[i]
#                 alist[i]= alist[i+1]
#                 alist[i+1] = temp
#
# LeerArchivo('BDO.csv','BD.txt')
